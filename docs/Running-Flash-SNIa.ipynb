# %% [markdown]
# # Compiling and Running a SNIa_ddt Flash Simulation
#
# Donald E. Willcox

# %% [markdown]
# ## Preparing to compile Flash

# %% [markdown]
# First navigate to the `Flash` directory, here called `autoDDT_dens_thresh`

# %%
cd ~/codes/astro/flash/autoDDT_dens_thresh
ls
# Out:
# bin    LICENSE		     setup		      setup_snia_ddt.sh   tools
# build  obj_GradDetParamBurn  setup_alt		      setup_snia_hddt.sh
# docs   RELEASE		     setup_commands	      sites
# lib    RELEASE-NOTES	     setup_snia_ddt_htest.sh  source

# %% [markdown]
# The `sites` subdirectory contains a set of directories named according to machine host names. Each of these directories contains the file `Makefile.h` which stores the settings `make` needs to build `Flash` for that machine.

# %%
cd sites
ls
# Out:
# alc.llnl.gov		     jacquard.nersc.gov
# Aliases			     jaguar.ccs.ornl.gov
# animal5			     jaguar.nccs.gov
# archimedes.uchicago.edu      jubl.zam.kfa-juelich.de
# bassi.nersc.gov		     karloff.lbl.gov
# bgl.llnl.gov		     khorba.uchicago.edu
# bgl.mcs.anl.gov		     klaus-laptop
# bgl.sdsc.edu		     kraken.nics.tennessee.edu
# bonsai.cfa.harvard.edu	     lenovolaptop
# brassica.asci.uchicago.edu   liturchi.uchicago.edu
# buckbeak		     login1.pads.ci.uchicago.edu
# cetus.asci.uchicago.edu      login2.pads.ci.uchicago.edu
# clark.asci.uchicago.edu      lupin.uchicago.edu
# code.uchicago.edu	     mhd2.asci.uchicago.edu
# coyote.lanl.gov		     miralac1
# cthinkpad		     mongchi.uchicago.edu
# ctsv.astro.sunysb.edu	     myristica.asci.uchicago.edu
# cube.uchicago.edu	     nagini.uchicago.edu
# datastar.sdsc.edu	     nightowl
# duce.gsfc.nasa.gov	     oakley.osc.edu
# elan.uchicago.edu	     optix.cs.uoregon.edu
# eldorado.astro.sunysb.edu    osel.uchicago.edu
# eldorado.uchicago.edu	     p655-4.nic.uoregon.edu
# ellipse02.uchicago.edu	     Prototypes
# ellipse03.uchicago.edu	     purple.llnl.gov
# ellipse04.uchicago.edu	     pyramid.uchicago.edu
# ellipse05.uchicago.edu	     qsc.lanl.gov
# ellipse06.uchicago.edu	     r1.oit.ua.edu
# ellipse08.uchicago.edu	     ramsusii.mps.ohio-state.edu
# ellipse09.uchicago.edu	     ranger.tacc.utexas.edu
# ellipse10.uchicago.edu	     rc2.ua.edu
# ellipse11.uchicago.edu	     redstorm.sandia.gov
# ellipse_pgf.uchicago.edu     saguaro.fulton.asu.edu
# ellipse.uchicago.edu	     scarf.rl.ac.uk
# eugenia.asci.uchicago.edu    scooter.asci.uchicago.edu
# eureka.alcf.anl.gov	     seaborg.nersc.gov
# fen.bluegene.bnl.gov	     SEAS10927.gwu.edu
# fenp.bluegene.bnl.gov	     skeeter.asci.uchicago.edu
# flash.uchicago.edu	     sphere.uchicago.edu
# flashviz.uchicago.edu	     splash.seas.gwu.edu
# fleetwood.astro.sunysb.edu   sunspot.uchicago.edu
# fornax.uchicago.edu	     surveyor.alcf.anl.gov
# franklin.nersc.gov	     tagore-jr
# fusion.lcrc.anl.gov	     tp-login2
# fusion.lcrc.uchicago.edu     tsoodzil.astro.uiuc.edu
# gin.asci.uchicago.edu	     tuxedo.uchicago.edu
# handy.cm.cluster	     uffda.asci.uchicago.edu
# hawkmoon.uchicago.edu	     variable.as.arizona.edu
# hera.llnl.gov		     variable.ph.ua.edu
# hpc.msu.edu		     vestalac1
# hydra.si.edu		     watanlsn.watson.ibm.com
# icc-9.0_fornax.uchicago.edu  zeus.llnl.gov
# ignition		     zingiber.asci.uchicago.edu
# intrepid.alcf.anl.gov	     zingiber.uchicago.edu

# %% [markdown]
# To get my machine host name, I'll use the `hostname` command.

# %%
hostname
# Out:
# snia-laptop

# %% [markdown]
# The `make` settings from `eldorado.astro.sunysb.edu` are typical for a workstation or laptop like mine so I'll just copy its directory to a new directory named according to the output of the `hostname` command. The expression `$(hostname)` in `bash` evaluates the command between the parentheses and substitutes the result of that command for the expression `$(hostname)`.

# %%
cp -r eldorado.astro.sunysb.edu $(hostname)

# %% [markdown]
# The previous command created a new directory called `snia-laptop`, and I can see that it contains a `Makefile.h`

# %%
cd snia-laptop
ls
# Out:
# Makefile.h

# %% [markdown]
# ## Compiling Flash

# %% [markdown]
# Now that I've created a directory in `sites` with the same name as my machine hostname, I can setup and compile `Flash`. First let's return to the `Flash` top-level directory.

# %%
cd ~/codes/astro/flash/autoDDT_dens_thresh
ls
# Out:
# bin    LICENSE		     setup		      setup_snia_ddt.sh   tools
# build  obj_GradDetParamBurn  setup_alt		      setup_snia_hddt.sh
# docs   RELEASE		     setup_commands	      sites
# lib    RELEASE-NOTES	     setup_snia_ddt_htest.sh  source

# %% [markdown]
# On my computer, I installed python via the Anaconda package. Using the following command, I can list the available python environments. The default environment for me, called `root` below, is python 3, but we need python 2 to setup `Flash` for compiling, so I need to switch to the `py2` environment.

# %%
conda info --envs
# Out:
# # conda environments:
# #
# py2                      /home/eugene/anaconda3/envs/py2
# root                  *  /home/eugene/anaconda3

# %% [markdown]
# Here I switch to the `py2` environment where `python --version` will tell me I have access to python 2. When I'm in the python 2 environment, the text `(py2)` will be printed when I execute commands, so just ignore that in the remainder of this section.

# %%
source activate py2
# Out:
# (py2)
# : 1

# %% [markdown]
# Now let's have a look at the contents of the `bash` script `setup_snia_ddt.sh`, which calls the `setup` script for `Flash`. `Flash` is capable of doing many kinds of simulations, but I'm specifically interested in a Type Ia Supernova deflagration-to-detonation transition simulation, and I tell the `setup` script to build just such a simulation by writing `SNIa_ddt` after `./setup`.
#
# Next comes `-objdir=` that specifies the directory where `setup` will put the source code I will need to compile in order to build a `SNIa_ddt` simulation.
#
# `-2d` specifies I want a two-dimensional domain
#
# `-nxb` is the number of blocks in the first dimension. Blocks are just chunks of individual grid cells in the domain.
#
# `-nyb` is the number of blocks in the second dimension.
#
# I'm being careful to say "first" and "second" because in the above options, `x` and `y` do not imply cartesian coordinates. In fact, the next option `+cylindrical` sets up a cylindrical 2-D axisymmetric coordinate system, where the "first" coordinate is the polar radial coordinate and the "second" coordinate is the axial coordinate.
#
# `-maxblocks=` specifies the maximum number of blocks `Flash` will assign to any given processor.
#
# `-with-unit=Particles/ParticlesMain` tells setup to include particles in this simulation. For `SNIa_ddt`, these are passive particles (they don't interact with the simulation physics) that just get carried around, advected along the fluid flow recording the thermodynamic state of the fluid so we can do post-processing later and do detailed nucleosynthesis calculations.

# %%
cat setup_snia_ddt.sh
# Out:
# ./setup SNIa_ddt -objdir=build/object_snia_ddt -2d -auto -nxb=16 -nyb=16 +cylindrical -maxblocks=10000 -with-unit=Particles/ParticlesMain
# (py2)
# : 1

# %% [markdown]
# And now let's try running the setup script.

# %%
./setup_snia_ddt.sh
# Out:
# Processing Shortcut file:
# /home/eugene/codes/astro/flash/autoDDT_dens_thresh/bin/setup_shortcuts.txt
# checking for needed files and directories
#     checking sites Aliases file
#     using site directory for site snia-laptop
# generating default Units file
#     Driver/DriverMain/Split
#     Grid/GridBoundaryConditions
#     Grid/GridMain/paramesh/interpolation/Paramesh4/prolong
#     Grid/GridMain/paramesh/interpolation/prolong
#     Grid/GridMain/paramesh/paramesh4/Paramesh4dev/PM4_package/headers
#     Grid/GridMain/paramesh/paramesh4/Paramesh4dev/PM4_package/mpi_source
#     Grid/GridMain/paramesh/paramesh4/Paramesh4dev/PM4_package/source
#     Grid/GridMain/paramesh/paramesh4/Paramesh4dev/PM4_package/utilities/multigrid
#     Grid/GridParticles/GridParticlesMapFromMesh
#     Grid/GridParticles/GridParticlesMove/Sieve/BlockMatch
#     Grid/GridParticles/GridParticlesMove/paramesh/PointToPoint
#     Grid/GridSolvers/Multipole
#     Grid/localAPI
#     IO/IOMain/hdf5/serial/PM
#     IO/IOParticles/hdf5/serial
#     IO/localAPI
#     Particles/ParticlesInitialization/WithDensity/CellMassBins
#     Particles/ParticlesMain/passive/RungeKutta
#     Particles/ParticlesMapping/meshWeighting/CIC
#     Particles/localAPI
#     PhysicalConstants/PhysicalConstantsMain
#     RuntimeParameters/RuntimeParametersMain
#     Simulation/SimulationComposition/Burn
#     Simulation/SimulationMain/SNIa_ddt
#     flashUtilities/contiguousConversion
#     flashUtilities/general
#     flashUtilities/interpolation/oneDim
#     flashUtilities/nameValueLL
#     flashUtilities/sorting
#     flashUtilities/system/memoryUsage/legacy
#     monitors/Logfile/LogfileMain
#     monitors/Timers/TimersMain/MPINative
#     physics/Eos/EosMain/Helmholtz/ExternalAbarZbar
#     physics/Eos/localAPI
#     physics/Gravity/GravityMain/Poisson/Multipole
#     physics/Hydro/HydroMain/split/PPM/PPMKernel
#     physics/materialProperties/NSE/NSEMain
#     physics/sourceTerms/Burn/BurnMain/parametric/CONe2NSE
#     physics/sourceTerms/Flame/FlameEffects/BurnParametric
#     physics/sourceTerms/Flame/FlameMain/RDSplit5point
#     physics/sourceTerms/Flame/FlameSpeed/BuoyancyCompensation/CONe
#     physics/sourceTerms/Flame/FlameSpeed/laminar/CONe
#     physics/sourceTerms/Flame/FlameSpeed/turbulent
# scanning
# /home/eugene/codes/astro/flash/autoDDT_dens_thresh/build/object_snia_ddt/Units
# file for included units
#     Driver/DriverMain/Split
#     Grid/GridBoundaryConditions
#     Grid/GridMain/paramesh/interpolation/Paramesh4/prolong
#     Grid/GridMain/paramesh/interpolation/prolong
#     Grid/GridMain/paramesh/paramesh4/Paramesh4dev/PM4_package/headers
#     Grid/GridMain/paramesh/paramesh4/Paramesh4dev/PM4_package/mpi_source
#     Grid/GridMain/paramesh/paramesh4/Paramesh4dev/PM4_package/source
#     Grid/GridMain/paramesh/paramesh4/Paramesh4dev/PM4_package/utilities/multigrid
#     Grid/GridParticles/GridParticlesMapFromMesh
#     Grid/GridParticles/GridParticlesMove/Sieve/BlockMatch
#     Grid/GridParticles/GridParticlesMove/paramesh/PointToPoint
#     Grid/GridSolvers/Multipole
#     Grid/localAPI
#     IO/IOMain/hdf5/serial/PM
#     IO/IOParticles/hdf5/serial
#     IO/localAPI
#     Particles/ParticlesInitialization/WithDensity/CellMassBins
#     Particles/ParticlesMain/passive/RungeKutta
#     Particles/ParticlesMapping/meshWeighting/CIC
#     Particles/localAPI
#     PhysicalConstants/PhysicalConstantsMain
#     RuntimeParameters/RuntimeParametersMain
#     Simulation/SimulationComposition/Burn
#     Simulation/SimulationMain/SNIa_ddt
#     flashUtilities/contiguousConversion
#     flashUtilities/general
#     flashUtilities/interpolation/oneDim
#     flashUtilities/nameValueLL
#     flashUtilities/sorting
#     flashUtilities/system/memoryUsage/legacy
#     monitors/Logfile/LogfileMain
#     monitors/Timers/TimersMain/MPINative
#     physics/Eos/EosMain/Helmholtz/ExternalAbarZbar
#     physics/Eos/localAPI
#     physics/Gravity/GravityMain/Poisson/Multipole
#     physics/Hydro/HydroMain/split/PPM/PPMKernel
#     physics/materialProperties/NSE/NSEMain
#     physics/sourceTerms/Burn/BurnMain/parametric/CONe2NSE
#     physics/sourceTerms/Flame/FlameEffects/BurnParametric
#     physics/sourceTerms/Flame/FlameMain/RDSplit5point
#     physics/sourceTerms/Flame/FlameSpeed/BuoyancyCompensation/CONe
#     physics/sourceTerms/Flame/FlameSpeed/laminar/CONe
#     physics/sourceTerms/Flame/FlameSpeed/turbulent
# Computing default values for options not specified on command line
#
#     INFO: Parameter useBurn defined in both
#     physics/sourceTerms/Burn (default FALSE) and
#     Simulation/SimulationMain/SNIa_ddt (default true)
#     Simulation instance overrides; removing other instance.
#
#     INFO: Parameter bn_thermalReact defined in both
#     Simulation/SimulationMain/SNIa_ddt (default false) and
#     physics/sourceTerms/Burn/BurnMain/parametric/CONe2NSE (default true)
#     Simulation instance overrides; removing other instance.
# Using Makefile.h: /home/eugene/codes/astro/flash/autoDDT_dens_thresh/sites/snia-laptop/Makefile.h
# generating Makefile
# Copying data files: 6 copied
# SUCCESS
# (py2)
# : 1

# %% [markdown]
# We see "SUCCESS" printed above, so the setup script finished successfully and made a directory with the source files we need to compile. Let's change directories to compile our simulation.

# %%
cd build/object_snia_ddt
ls
# Out:
# (py2) amr_1blk_bcset.F90		     Heatexchange_init.F90
# amr_1blk_cc_cp_remote.F90	     Heatexchange_interface.F90
# amr_1blk_cc_prol_genorder.F90	     Heat.F90
# amr_1blk_cc_prol_gen_unk_fun.F90     Heat_finalize.F90
# amr_1blk_cc_prol_gen_work_fun.F90    Heat_init.F90
# amr_1blk_cc_prol_inject.F90	     Heat_interface.F90
# amr_1blk_cc_prol_linear.F90	     helm_table.dat
# amr_1blk_cc_prol_user.F90	     hydro_1d.F90
# amr_1blk_cc_prol_work_genorder.F90   Hydro_computeDt.F90
# amr_1blk_cc_prol_work_inject.F90     Hydro_data.F90
# amr_1blk_cc_prol_work_linear.F90     Hydro_detectShock.F90
# amr_1blk_cc_prol_work_user.F90	     Hydro.F90
# amr_1blk_copy_soln.F90		     Hydro_finalize.F90
# amr_1blk_ec_cp_remote.F90	     Hydro_init.F90
# amr_1blk_ec_prol_gen_fun.F90	     Hydro_interface.F90
# amr_1blk_ec_prol_genorder.F90	     Hydro_recalibrateEints.F90
# amr_1blk_ec_prol_linear.F90	     Hydro_sendOutputData.F90
# amr_1blk_ec_prol_user.F90	     Hydro_shockStrength.F90
# amr_1blk_fc_clean_divb.F90	     hy_interpNoLim.F90
# amr_1blk_fc_cp_remote.F90	     hy_nomonot.F90
# amr_1blk_fc_prol_dbz.F90	     hy_ppm_block.F90
# amr_1blk_fc_prol_gen_fun.F90	     hy_ppm_completeGeomFactors.F90
# amr_1blk_fc_prol_genorder.F90	     hy_ppm_force.F90
# amr_1blk_fc_prol_inject.F90	     hy_ppm_geom.F90
# amr_1blk_fc_prol_linear.F90	     hy_ppm_getTemporaryData.F90
# amr_1blk_fc_prol_user.F90	     hy_ppm_interface.F90
# amr_1blk_guardcell_reset.F90	     hy_ppm_putTemporaryData.F90
# amr_1blk_guardcell_srl.F90	     hy_ppm_sweep.F90
# amr_1blk_nc_cp_remote.F90	     hy_ppm_updateSoln.F90
# amr_1blk_nc_prol_gen_fun.F90	     INSTALL.py
# amr_1blk_nc_prol_genorder.F90	     interp_char.F90
# amr_1blk_nc_prol_linear.F90	     interp.F90
# amr_1blk_nc_prol_user.F90	     intrfc.F90
# amr_1blk_save_soln.F90		     io_attribute.c
# amr_1blk_to_perm.F90		     io_attribute.h
# amr_1blk_t_to_perm.F90		     io_bcastScalars.F90
# amr_bcset_init.F90		     IO_checkForPlot.F90
# amr_block_geometry.F90		     io_c_interface.F90
# amr_check_refine.F90		     io_closeFile.F90
# amr_close.F90			     io_comp_decomp.c
# amr_compute_morton.F90		     io_comp_decomp.h
# amr_get_new_nodetypes.F90	     io_compressDecompress.c
# amr_initialize.F90		     io_compressDecompress.h
# amr_mg_common.F90		     io_create_dataset.c
# amr_mg_init.F90			     io_create_dataset.h
# amr_mg_morton_process.F90	     IO_data.F90
# amr_mg_prolong.F90		     IO_endRayWrite.F90
# amr_mg_restrict.F90		     io.F90
# amr_migrate_tree_data.F90	     IO_finalize.F90
# amr_morton_order.F90		     io_finalizeListsRead.F90
# amr_morton_process.F90		     io_finalizeListsWrite.F90
# amr_mpi_find_blk_in_buffer.F90	     io_flash.h
# amr_perm_to_1blk.F90		     io_getAllScalars.F90
# amr_prolong_cc_fun_init.F90	     io_getNumScalars.F90
# amr_prolong_face_fun_init.F90	     io_getOutputName.F90
# amr_prolong_fun_init.F90	     io_getParticleOffset.F90
# amr_prolong_gen_unk1_fun.F90	     IO_getPrevScalar.F90
# amr_prolong_gen_work1_fun.F90	     IO_getScalar.F90
# amr_q_sort.F90			     io_getVarExtrema.F90
# amr_q_sort_real.F90		     io_h5_attribute.c
# amr_reorder_grid.F90		     io_h5_attribute.h
# amr_restrict_ec_fun.F90		     io_h5create_dataset.c
# amr_restrict_ec_genorder.F90	     io_h5create_dataset.h
# amr_restrict_ec_user.F90	     io_h5create_raydset.c
# amr_restrict_edge.F90		     io_h5file_interface.c
# amr_restrict_fc_fun.F90		     io_h5read_bflags.c
# amr_restrict_fc_genorder.F90	     io_h5read_blk_particle_info.c
# amr_restrict_fc_user.F90	     io_h5read_blksize.c
# amr_restrict_nc_fun.F90		     io_h5read_bndbox.c
# amr_restrict_nc_genorder.F90	     io_h5read_coords.c
# amr_restrict_nc_user.F90	     io_h5read_generic_int_arr.c
# amr_restrict_red.F90		     io_h5read_generic_real_arr.c
# amr_restrict_unk_fun.F90	     io_h5read_gid.c
# amr_restrict_unk_genorder.F90	     io_h5read_globalintvect.c
# amr_restrict_unk_user.F90	     io_h5read_globalstrvect.c
# amr_restrict_work_fun.F90	     io_h5read_header.c
# amr_restrict_work_fun_recip.F90      io_h5read_lists.c
# amr_restrict_work_genorder.F90	     io_h5read_localnp.c
# amr_restrict_work_user.F90	     io_h5read_lrefine.c
# amr_set_runtime_parameters.F90	     io_h5read_nodetype.c
# amr_sort_by_work.F90		     io_h5read_num_props.c
# amr_sort_morton.F90		     io_h5read_particle_names.c
# amr_sort_morton_reorder_grid.F90     io_h5read_particles.c
# amr_system_calls.F90		     io_h5read_single_part_prop.c
# avisco.F90			     io_h5read_unknowns.c
# bn_paraAllIgnite.F90		     io_h5read_which_child.c
# bn_paraAllSpark.F90		     io_h5_type.c
# bn_paraBurn.F90			     io_h5_type.h
# bn_paraFuelAshProperties.F90	     io_h5_type_matched_xfer.c
# bn_paraInterface.F90		     io_h5_type_matched_xfer.h
# bn_paraSpark.F90		     io_h5write_bflags.c
# Burn_computeDt.F90		     io_h5write_blk_particle_info.c
# Burn_data.F90			     io_h5write_blksize.c
# Burn.F90			     io_h5write_blksize_sp.c
# Burn_finalize.F90		     io_h5write_bndbox.c
# Burn_init.F90			     io_h5write_bndbox_sp.c
# Burn_interface.F90		     io_h5write_coords.c
# Burn_nseAtDens.F90		     io_h5write_coords_sp.c
# Burn_nseAtPres.F90		     io_h5write_generic_int_arr.c
# cc_7e8_linear_wd_plain.dat	     io_h5write_generic_real_arr.c
# clean_divb.fh			     io_h5write_gid.c
# clean_field.F90			     io_h5write_header.c
# cma_flatten.F90			     io_h5write_lists.c
# coeff.F90			     io_h5write_localnp.c
# compress_fetch_list.F90		     io_h5write_lrefine.c
# concatStringWithInt.F90		     io_h5write_nodetype.c
# Conductivity.F90		     io_h5write_particles.c
# Conductivity_finalize.F90	     io_h5write_procnumber.c
# Conductivity_init.F90		     io_h5write_raydata.c
# Conductivity_interface.F90	     io_h5write_unknowns.c
# CONeFlameTable.txt		     io_h5write_unknowns_sp.c
# constants.F90			     io_h5write_which_child.c
# constants.h			     io_h5_xfer.c
# Cool_computeDt.F90		     io_h5_xfer.h
# Cool.F90			     io_h5_xfer_wrapper.c
# Cool_finalize.F90		     io_h5_xfer_wrapper.h
# Cool_init.F90			     IO_init.F90
# Cool_interface.F90		     io_initFile.F90
# Cool_unitTest.F90		     IO_initRPsFromCheckpoint.F90
# Cosmology_cdmPowerSpectrum.F90	     IO_interface.F90
# Cosmology_computeDeltaCrit.F90	     io_isPlotVar.F90
# Cosmology_computeDt.F90		     io_memoryReport.F90
# Cosmology_computeVariance.F90	     io_mpi_type.c
# Cosmology_finalize.F90		     io_mpi_type.h
# Cosmology_getOldRedshift.F90	     Ionize_equil.F90
# Cosmology_getParams.F90		     Ionize.F90
# Cosmology_getRedshift.F90	     Ionize_finalize.F90
# Cosmology_init.F90		     Ionize.h
# Cosmology_interface.F90		     Ionize_init.F90
# Cosmology_massToLength.F90	     Ionize_interface.F90
# Cosmology_redshiftHydro.F90	     IO_output.F90
# Cosmology_redshiftToTime.F90	     IO_outputFinal.F90
# Cosmology_sendOutputData.F90	     IO_outputInitial.F90
# Cosmology_solveFriedmannEqn.F90      IOParticles_data.F90
# Cosmology_unitTest.F90		     io_prepareListsRead.F90
# current_date_time.F90		     io_prepareListsWrite.F90
# default.par			     io_prepareSimInfo.F90
# Deleptonize.F90			     io_ptCorrectNextPartTime.F90
# Deleptonize_finalize.F90	     io_ptCreateSubset.F90
# Deleptonize_getBounce.F90	     io_ptInit.F90
# Deleptonize_init.F90		     io_ptInterface.F90
# Deleptonize_interface.F90	     io_ptReadParticleData.F90
# detect.F90			     io_ptResetNextFile.F90
# Diffuse_advance1D.F90		     io_ptSendOutputData.F90
# Diffuse_computeDt.F90		     io_ptWriteParticleData.F90
# Diffuse.F90			     IO_readCheckpoint.F90
# Diffuse_finalize.F90		     io_readData.F90
# Diffuse_fluxLimiter.F90		     IO_readParticles.F90
# Diffuse_init.F90		     io_readRPsFromCheckpoint.F90
# Diffuse_interface.F90		     IO_readUserArray.F90
# Diffuse_solveScalar.F90		     io_restrictBeforeWrite.F90
# Diffuse_species.F90		     IO_sendOutputData.F90
# Diffuse_therm.F90		     io_setPrevScalar.F90
# Diffuse_visc.F90		     IO_setScalar.F90
# Driver_abortFlashC.c		     IO_startRayWrite.F90
# Driver_abortFlash.F90		     io_typeInterface.F90
# Driver_checkMPIErrorCode.F90	     IO_updateScalars.F90
# Driver_computeDt.F90		     IO_writeCheckpoint.F90
# Driver_computeDtTemp.F90	     io_writeData.F90
# Driver_data.F90			     IO_writeIntegralQuantities.F90
# Driver_driftBlock.F90		     IO_writeParticles.F90
# Driver_driftSetSrcLoc.F90	     IO_writePlotfile.F90
# Driver_driftUnk.F90		     IO_writeRays.F90
# Driver_evolveFlash.F90		     IO_writeUserArray.F90
# Driver_finalizeFlash.F90	     io_xfer_cont_slab.c
# Driver_finalizeSourceTerms.F90	     io_xfer_cont_slab.h
# Driver_getComm.F90		     io_xfer_tree_data.F90
# Driver_getDt.F90		     local_tree_build.F90
# Driver_getElapsedWCTime.F90	     local_tree.F90
# Driver_getMype.F90		     log_allocateStrArr.F90
# Driver_getNStep.F90		     Logfile_break.F90
# Driver_getNumProcs.F90		     Logfile_close.F90
# Driver_getSimTime.F90		     Logfile_create.F90
# Driver_getTimeStamp.F90		     Logfile_data.F90
# Driver_init.F90			     Logfile_finalize.F90
# Driver_initFlash.F90		     Logfile_getDateTimeStr.F90
# Driver_initMaterialProperties.F90    Logfile_init.F90
# Driver_initParallel.F90		     Logfile_interface.F90
# Driver_initSourceTerms.F90	     Logfile_open.F90
# Driver_interface.F90		     Logfile_stamp.F90
# Driver_logMemoryUsage.F90	     Logfile_stampMessage.F90
# Driver_mpiThreadSupport.F90	     Logfile_stampVarMask.F90
# Driver_putTimeStamp.F90		     Logfile_writeSummary.F90
# Driver_sendOutputData.F90	     log_getUnitsArr.F90
# Driver_setupParallelEnv.F90	     MagneticResistivity.F90
# Driver_sourceTerms.F90		     MagneticResistivity_finalize.F90
# Driver_superTimeStep.F90	     MagneticResistivity_init.F90
# Driver_verifyInitDt.F90		     MagneticResistivity_interface.F90
# dr_set_rlimits.c		     make_bstamp
# dr_shortenLastDt.F90		     make_bstats
# dr_sleep.c			     Makefile
# EnergyDeposition.F90		     Makefile.Burn
# EnergyDeposition_finalize.F90	     Makefile.Conductivity
# EnergyDeposition_init.F90	     Makefile.Cool
# EnergyDeposition_interface.F90	     Makefile.Cosmology
# Eos_data.F90			     Makefile.Deleptonize
# eos_externalComputeAbarZbar.F90      Makefile.Diffuse
# Eos.F90				     Makefile.Driver
# eos_fillMapLookup.F90		     Makefile.EnergyDeposition
# Eos_finalize.F90		     Makefile.Eos
# Eos_getAbarZbar.F90		     Makefile.Flame
# Eos_getData.F90			     Makefile.flashUtilities
# Eos_getParameters.F90		     Makefile.Gravity
# Eos_getTempData.F90		     Makefile.Grid
# Eos_guardCells.F90		     Makefile.h
# Eos.h				     Makefile.Heat
# eos_helmConstData.F90		     Makefile.Heatexchange
# eos_helmData.F90		     Makefile.Hydro
# eos_helm.F90			     Makefile.IO
# eos_helmholtz.F90		     Makefile.Ionize
# eos_helmInterface.F90		     Makefile.Logfile
# eos_idealGamma3T.F90		     Makefile.MagneticResistivity
# eos_idealGamma.F90		     Makefile.MassDiffusivity
# Eos_init.F90			     Makefile.Multispecies
# eos_initGamma.F90		     Makefile.NSE
# eos_initHelmholtz.F90		     Makefile.Opacity
# eos_initMgamma.F90		     Makefile.Particles
# eos_initMtemp.F90		     Makefile.PhysicalConstants
# eos_initNuclear.F90		     Makefile.Polytrope
# eos_initTabulated.F90		     Makefile.PrimordialChemistry
# Eos_interface.F90		     Makefile.Profiler
# eos_localInterface.F90		     Makefile.RadTrans
# Eos_logDiagnostics.F90		     Makefile.RuntimeParameters
# Eos_map.h			     Makefile.Simulation
# eos_mgamma.F90			     Makefile.Stir
# eos_mtemp.F90			     Makefile.Timers
# eos_mtInterface.F90		     Makefile.Turb
# eos_nuclear.F90			     Makefile.Viscosity
# Eos_nucOneZone.F90		     makeLowercase.F90
# Eos_putData.F90			     make_release
# eos_readHfet.F90		     mangle_names.h
# eos_tabFinalize.F90		     MassDiffusivity.F90
# eos_tabInterface.F90		     MassDiffusivity_finalize.F90
# eos_tabIonmix.F90		     MassDiffusivity_init.F90
# eos_tabulated.F90		     MassDiffusivity_interface.F90
# eos_tools.c			     monot.F90
# Eos_unitTest.F90		     morton_sort.F90
# eos_variableMap.F90		     mpi_amr_1blk_guardcell_c_to_f.F90
# eos_vecAlloc.F90		     mpi_amr_1blk_guardcell.F90
# eos_vecData.F90			     mpi_amr_1blk_restrict.F90
# eos_vecDealloc.F90		     mpi_amr_boundary_block_info.F90
# Eos_wrapped.F90			     mpi_amr_check_derefine.F90
# eos_writeHfet.F90		     mpi_amr_checkpoint_re_default.F90
# fill_old_loc.F90		     mpi_amr_checkpoint_re.F90
# find_surrblks.F90		     mpi_amr_checkpoint_re_hdf5.F90
# findWords.F90			     mpi_amr_checkpoint_re_mpiio.F90
# Flame_data.F90			     mpi_amr_checkpoint_wr_default.F90
# Flame_finalize.F90		     mpi_amr_checkpoint_wr.F90
# Flame_getProfile.F90		     mpi_amr_checkpoint_wr_hdf5.F90
# Flame_getWidth.F90		     mpi_amr_checkpoint_wr_mpiio.F90
# Flame_init.F90			     mpi_amr_comm_setup.F90
# Flame_interface.F90		     mpi_amr_derefine_blocks.F90
# Flame_laminarSpeed.F90		     mpi_amr_edge_average.F90
# Flame_rhJump.F90		     mpi_amr_edge_average_udt.F90
# Flame_rhJumpReactive.F90	     mpi_amr_edge_average_vdt.F90
# Flame_step.F90			     mpi_amr_edge_diagonal_check.F90
# flash_convert_cc_hook.F90	     mpi_amr_flux_conserve.F90
# Flash.F90			     mpi_amr_flux_conserve_udt.F90
# Flash.h				     mpi_amr_flux_conserve_vdt.F90
# Flash_mpi.h			     mpi_amr_get_remote_block.F90
# flash.par			     mpi_amr_get_remote_block_fvar.F90
# flash_unconvert_cc_hook.F90	     mpi_amr_global_domain_limits.F90
# flaten.F90			     mpi_amr_guardcell.F90
# fl_effData.F90			     mpi_amr_local_surr_blks_lkup.F90
# fl_effects.F90			     mpi_amr_plotfile_chombo.F90
# fl_effFinalize.F90		     mpi_amr_prolong.F90
# fl_effInit.F90			     mpi_amr_prolong_fc_divbconsist.F90
# fl_effInterface.F90		     mpi_amr_redist_blk.F90
# fl_flameSpeed.F90		     mpi_amr_refine_blocks.F90
# fl_fsAtwoodData.F90		     mpi_amr_refine_derefine.F90
# fl_fsAtwoodEndTable.F90		     mpi_amr_restrict_bnd_data.F90
# fl_fsAtwood.F90			     mpi_amr_restrict_bnd_data_vdt.F90
# fl_fsAtwoodInitTable.F90	     mpi_amr_restrict_edge_data.F90
# fl_fsAtwoodInterface.F90	     mpi_amr_restrict_edge_data_vdt.F90
# fl_fsConeData.F90		     mpi_amr_restrict.F90
# fl_fsConeInterp.F90		     mpi_amr_restrict_fulltree.F90
# fl_fsData.F90			     mpi_amr_singular_line.F90
# fl_fsFinalize.F90		     mpi_amr_store_comm_info.F90
# fl_fsGcMask.F90			     mpi_amr_store_comm_info_mg.F90
# fl_fsInit.F90			     mpi_amr_test_neigh_values.F90
# fl_fsInterface.F90		     mpi_amr_timing_report.F90
# fl_fsLaminarFinalize.F90	     mpi_amr_tree_setup.F90
# fl_fsLaminarFlameSpeedBlock.F90      mpi_get_buffer.F90
# fl_fsLaminarInit.F90		     mpi_get_edge_buffer.F90
# fl_fsLaminarInterface.F90	     mpi_get_flux_buffer.F90
# fl_fsTFIFinalize.F90		     mpi_lib.F90
# fl_fsTFIFlameSpeedBlock.F90	     mpi_morton_bnd.F90
# fl_fsTFIFunc.F90		     mpi_morton_bnd_fluxcon.F90
# fl_fsTFIGcMask.F90		     mpi_morton_bnd_prolong.F90
# fl_fsTFIInit.F90		     mpi_morton_bnd_restrict.F90
# fl_fsTFIInterface.F90		     mpi_morton.F90
# fl_fsUnburnDensBlock.F90	     mpi_pack_blocks.F90
# fl_fsUnburnDens.F90		     mpi_pack_edges.F90
# fl_interface.F90		     mpi_pack_fluxes.F90
# fl_laplacian.F90		     mpi_pack_tree_info.F90
# gr_amr_dump_runtime_parameters.F90   mpi_put_buffer.F90
# Gravity_accelAtCoords.F90	     mpi_put_edge_buffer_1blk.F90
# Gravity_accelListOfBlocks.F90	     mpi_put_edge_buffer.F90
# Gravity_accelOneBlock.F90	     mpi_put_flux_buffer.F90
# Gravity_accelOneRow.F90		     mpi_set_message_limits.F90
# Gravity_computeDt.F90		     mpi_set_message_limits_unpack.F90
# Gravity_data.F90		     mpi_set_message_sizes.F90
# Gravity_finalize.F90		     mpi_unpack_blocks.F90
# Gravity_init.F90		     mpi_unpack_edges.F90
# Gravity_interface.F90		     mpi_unpack_fluxes.F90
# Gravity_potentialListOfBlocks.F90    mpi_unpack_tree_info.F90
# Gravity_unitTest.F90		     mpi_wrapper_dble.F90
# gr_bcApplyToAllBlks.F90		     mpi_wrapper_int.F90
# gr_bcApplyToOneFace.F90		     mpi_wrapper_logical.F90
# gr_bcData.F90			     mpi_wrapper_real.F90
# gr_bcFinalize.F90		     Multispecies_finalize.F90
# gr_bcGetRegion.F90		     Multispecies_getAvg.F90
# gr_bcHseInit.F90		     Multispecies_getProperty.F90
# gr_bcInit.F90			     Multispecies_getPropertyVector.F90
# gr_bcInterface.F90		     Multispecies_getSum.F90
# gr_bcMapBcType.F90		     Multispecies_getSumFrac.F90
# gr_bcPutRegion.F90		     Multispecies_getSumInv.F90
# gr_bhFinalize.F90		     Multispecies_getSumSqr.F90
# gr_bhInit.F90			     Multispecies.h
# gr_bhInterface.F90		     Multispecies_init.F90
# gr_bicgFinalize.F90		     Multispecies_interface.F90
# gr_bicgInit.F90			     Multispecies_list.F90
# gr_bicgInterface.F90		     Multispecies_setProperty.F90
# gr_bicgMapBcType.F90		     Multispecies_unitTest.F90
# gr_checkDataType.F90		     nameSyntaxError.F90
# gr_checkGridConsistency.F90	     nameValueLL_bcast.F90
# gr_checkGridState.F90		     nameValueLL_data.F90
# gr_commSetUp.F90		     nameValueLL_getAll.F90
# gr_computeMorton.F90		     nameValueLL_get.F90
# gr_conserveToPrimitive.F90	     nameValueLL_getNum.F90
# gr_createBlock.F90		     nameValueLL_logRules.F90
# gr_createDomain.F90		     nameValueLL_rules.F90
# grdvel.F90			     nameValueLL_set.F90
# gr_enforceMaxRefine.F90		     NSE_data.F90
# gr_ensureValidNeighborInfo.F90	     nse_dens_emq_table.txt
# gr_expandDomain.F90		     NSE_finalAtDens.F90
# gr_extendedGetCellCoords.F90	     NSE_finalAtPres.F90
# gr_extendedGetDeltas.F90	     NSE_finalize.F90
# gr_findAllNeghID.F90		     NSE_init.F90
# gr_findBlock.F90		     NSE_interface.F90
# gr_findMean.F90			     nse_pres_hmq_table.txt
# gr_findNeghID.F90		     Opacity.F90
# gr_findWhichChild.F90		     Opacity_finalize.F90
# gr_findWhichChildren.F90	     Opacity_init.F90
# gr_flashHook_interfaces.F90	     Opacity_interface.F90
# gr_freeCommRecvBuffer.F90	     Opacity_unitTest.F90
# gr_GCAllocScratch.F90		     paramesh_comm_data.F90
# gr_GCReleaseScratch.F90		     paramesh_dimensions.F90
# gr_GCScratchData.F90		     Paramesh_finalize.F90
# gr_GCTransferOneBlk.F90		     Paramesh_init.F90
# gr_getBlkHandle.F90		     paramesh_interfaces.F90
# gr_getCellFaceArea.F90		     paramesh_mpi_interfaces.F90
# gr_getCellVol.F90		     paramesh_preprocessor.fh
# gr_getDataOffsets.F90		     paramesh_reorder.h
# gr_getIndex.F90			     Particles_accumCount.F90
# gr_getInteriorBlkPtr.F90	     Particles_addNew.F90
# gr_hg_amr_1blk_bcset_work.F90	     Particles_advance.F90
# gr_hgFinalize.F90		     Particles_computeDt.F90
# gr_hgInit.F90			     Particles_data.F90
# gr_hgInterface.F90		     Particles_dump.F90
# gr_hgMapBcType.F90		     Particles_finalize.F90
# gr_hgPfftFinalize.F90		     Particles_getCountPerBlk.F90
# gr_hgPfftInit.F90		     Particles_getGlobalNum.F90
# gr_hypreAddGraph.F90		     Particles_getLocalNum.F90
# gr_hypreApplyBcToFace.F90	     Particles.h
# gr_hypreComputeB.F90		     Particles_initData.F90
# gr_hypreCreateMatrix.F90	     Particles_init.F90
# gr_hypreDestroyGrid.F90		     Particles_initForces.F90
# gr_hypreDestroySolver.F90	     Particles_initPositions.F90
# gr_hypreExchangeFacB.F90	     Particles_interface.F90
# gr_hypreFinalize.F90		     Particles_longRangeForce.F90
# gr_hypreGetFaceB.F90		     Particles_manageLost.F90
# gr_hypreGridStatus.F90		     Particles_mapFromMesh.F90
# gr_hypreInit.F90		     Particles_mapToMeshOneBlk.F90
# gr_hypreSetIniGuess.F90		     Particles_putLocalNum.F90
# gr_hypreSetupGrid.F90		     Particles_sendOutputData.F90
# gr_hypreSetupSolver.F90		     Particles_shortRangeForce.F90
# gr_hypreSolve.F90		     Particles_sinkAccelSinksOnGas.F90
# gr_hypreUpdateSoln.F90		     Particles_sinkAdvance.F90
# Grid_addToVar.F90		     Particles_sinkAdvanceParticles.F90
# Grid_advanceDiffusion.F90	     Particles_sinkComputeDt.F90
# Grid_applyBCEdgeAllUnkVars.F90	     Particles_sinkInit.F90
# Grid_applyBCEdge.F90		     Particles_sinkMarkRefineDerefine.F90
# Grid_bcApplyToRegion.F90	     Particles_sinkMoveParticles.F90
# Grid_bcApplyToRegionSpecialized.F90  Particles_sinkSendOutputData.F90
# Grid_computeUserVars.F90	     Particles_sinkSyncWithParticles.F90
# Grid_computeVarDiff.F90		     Particles_specifyMethods.F90
# Grid_computeVarNorm.F90		     Particles_unitTest.F90
# Grid_conserveField.F90		     Particles_updateAttributes.F90
# Grid_conserveFluxes.F90		     Particles_updateGridVar.F90
# Grid_conserveToPrimitive.F90	     Particles_updateRefinement.F90
# Grid_data.F90			     pc_interface.F90
# Grid_dump.F90			     pc_utilities.F90
# Grid_extendedGetBlkBC.F90	     PhysicalConstants_data.F90
# Grid_fillGuardCells.F90		     PhysicalConstants_get.F90
# Grid_finalize.F90		     PhysicalConstants_init.F90
# Grid_formatNonRep.F90		     PhysicalConstants_interface.F90
# Grid_GCPutScratch.F90		     PhysicalConstants_list.F90
# Grid_GCTransferOneBlk.F90	     PhysicalConstants_listUnits.F90
# Grid_getBlkBC.F90		     PhysicalConstants_unitTest.F90
# Grid_getBlkBoundBox.F90		     physicaldata.F90
# Grid_getBlkCenterCoords.F90	     poisson_sor.F90
# Grid_getBlkCornerID.F90		     Polytrope.F90
# Grid_getBlkData.F90		     Polytrope_finalize.F90
# Grid_getBlkIDFromPos.F90	     Polytrope_init.F90
# Grid_getBlkIndexLimits.F90	     Polytrope_interface.F90
# Grid_getBlkPhysicalSize.F90	     PPM.h
# Grid_getBlkPtr.F90		     PrimordialChemistry_computeDt.F90
# Grid_getBlkRefineLevel.F90	     PrimordialChemistry.F90
# Grid_getBlkType.F90		     PrimordialChemistry_finalize.F90
# Grid_getBoundboxCentroids.F90	     PrimordialChemistry_init.F90
# Grid_getCellCoords.F90		     PrimordialChemistry_interface.F90
# Grid_getDeltas.F90		     process_fetch_list.F90
# Grid_getDomainBC.F90		     Profiler_getSummary.F90
# Grid_getDomainBoundBox.F90	     Profiler.h
# Grid_getFluxData.F90		     Profiler_init.F90
# Grid_getGeometry.F90		     Profiler_interface.F90
# Grid_getGlobalIndexLimits.F90	     Profiler_start.F90
# Grid_getListOfBlocks.F90	     Profiler_stop.F90
# Grid_getLocalNumBlks.F90	     prolong_arrays.F90
# Grid_getMaxCommonRefinement.F90      pt_advanceCharged.F90
# Grid_getMinCellSize.F90		     pt_advanceCustom.F90
# Grid_getMinCellSizes.F90	     pt_advanceEsti.F90
# Grid_getNumVars.F90		     pt_advanceEuler_active.F90
# Grid_getPlaneData.F90		     pt_advanceEuler_passive.F90
# Grid_getPointData.F90		     pt_advanceLeapfrog_cosmo.F90
# Grid_getRowData.F90		     pt_advanceLeapfrog.F90
# Grid_getSingleCellCoords.F90	     pt_advanceMidpoint.F90
# Grid_getSingleCellVol.F90	     pt_advanceRK.F90
# Grid_getVarNonRep.F90		     pt_assignWeights.F90
# Grid_initDomain.F90		     pt_createTag.F90
# Grid_init.F90			     pt_findTagOffset.F90
# Grid_interface.F90		     pt_initFinalize.F90
# Grid_limitAbundance.F90		     pt_initLocal.F90
# Grid_mapMeshToParticles.F90	     pt_initPositions.F90
# Grid_mapParticlesToMesh.F90	     pt_initPositionsLattice.F90
# Grid_markBlkDerefine.F90	     pt_initPositionsWithDensity.F90
# Grid_markBlkRefine.F90		     pt_interface.F90
# Grid_markRefineDerefine.F90	     pt_mapFromMeshQuadratic.F90
# Grid_markRefineSpecialized.F90	     pt_mapFromMeshWeighted.F90
# Grid_moveParticles.F90		     pt_mapStringParamToInt.F90
# Grid_outsideBoundBox.F90	     pt_picInit.F90
# Grid_parseNonRep.F90		     pt_prepareEsti.F90
# GridParticles.h			     pt_setDataStructures.F90
# Grid_pfft.F90			     pt_setMask.F90
# Grid_pfftFinalize.F90		     pt_updateTypeDS.F90
# Grid_pfftGetIndexLimits.F90	     pt_utAnaGetNewPosComponents.F90
# Grid_pfftInit.F90		     pt_utComputeError.F90
# Grid_pfftMapFromOutput.F90	     pt_utFakeParticlesAdvance.F90
# Grid_pfftMapToInput.F90		     pt_utUpdateAnaPosns.F90
# Grid_primitiveToConserve.F90	     RadTrans_computeDt.F90
# Grid_putBlkData.F90		     RadTrans.F90
# Grid_putFluxData.F90		     RadTrans_finalize.F90
# Grid_putLocalNumBlks.F90	     RadTrans_init.F90
# Grid_putPlaneData.F90		     RadTrans_interface.F90
# Grid_putPointData.F90		     RadTrans_mgdEFromT.F90
# Grid_putRowData.F90		     RadTrans_mgdGetBound.F90
# Grid_releaseBlkPtr.F90		     RadTrans_mgdSetBc.F90
# Grid_renormAbundance.F90	     RadTrans_mgdSetBound.F90
# Grid_renormMassScalars.F90	     RadTrans_mgdSetEnergy.F90
# Grid_restrictAllLevels.F90	     RadTrans_planckInt.F90
# Grid_restrictByLevels.F90	     RadTrans_sumEnergy.F90
# Grid_sbBroadcastParticles.F90	     rationalize_fetch_list.F90
# Grid_sbCreateGroups.F90		     read_blocks_hdf5_r4.c
# Grid_sbSelectMaster.F90		     read_blocks_hdf5_r8.c
# Grid_sendOutputData.F90		     removeNullChar.F90
# Grid_setFluxHandling.F90	     reorder.tpl
# Grid_solidBodyUnitTest.F90	     resetup
# Grid_solvePoisson.F90		     rieman.F90
# Grid_sortParticles.F90		     riemann_hlle.F90
# Grid_unitTest.F90		     rp_getArgument.F90
# Grid_updateRefinement.F90	     rp_getOpt.F90
# Grid_updateSolidBodyForces.F90	     rp_initParameters.F90
# Grid_xyzToBlock.F90		     rp_rules.F90
# gr_initGeometry.F90		     rp_rules.h
# gr_initParameshArrays.F90	     rp_storeIgnoredParams.F90
# gr_initParameshDomainBboxes.F90      RuntimeParameters_add.F90
# gr_interface.F90		     RuntimeParameters_bcast.F90
# gr_interfaceTypeDecl.F90	     RuntimeParameters_data.F90
# gr_isoInterface.F90		     RuntimeParameters_finalize.F90
# gr_isoMpoleFinalize.F90		     RuntimeParameters_getAll.F90
# gr_isoMpoleInit.F90		     RuntimeParameters_get.F90
# gr_makeMaskConsistent.F90	     RuntimeParameters_getNum.F90
# gr_markDerefineByTime.F90	     RuntimeParameters_getNumIgn.F90
# gr_markEllipsoid.F90		     RuntimeParameters_getPrev.F90
# gr_markInRadius.F90		     RuntimeParameters_init.F90
# gr_markInRectangle.F90		     RuntimeParameters_interface.F90
# gr_markRefineDerefine.F90	     RuntimeParameters_mapStrToInt.F90
# gr_markVarThreshold.F90		     RuntimeParameters_read.F90
# gr_markWithRadius.F90		     RuntimeParameters_set.F90
# gr_mgFinalize.F90		     RuntimeParameters_setPrev.F90
# gr_mgInit.F90			     RuntimeParameters_stampIgnored.F90
# gr_mgInterface.F90		     send_block_data.F90
# gr_mgMapBcType.F90		     set_f2c_indexes.F90
# gr_mgPfftFinalize.F90		     setup_addcdepends.py
# gr_mgPfftInit.F90		     setup_call
# gr_mpoleAllocateRadialArrays.F90     setup_datafiles
# gr_mpoleCenterOfMass.F90	     setup_defines
# gr_mpoleCM1Dspherical.F90	     setup_depends.py
# gr_mpoleCM2Dcylindrical.F90	     setup_getFlashUnits.F90
# gr_mpoleCM2Dspherical.F90	     setup_libraries
# gr_mpoleCM3Dcartesian.F90	     setup_params
# gr_mpoleCollectMoments.F90	     setup_reorder.py
# gr_mpoleData.F90		     setup_units
# gr_mpoleDeallocateRadialArrays.F90   setup_vars
# gr_mpoleDumpMoments.F90		     sim_interpolate1dWd.F90
# gr_mpoleEvalBin.F90		     sim_LCGRandomIterate.F90
# gr_mpoleEvalBinsize.F90		     sim_local_interface.F90
# gr_mpoleFinalize.F90		     Simulation_adjustEvolution.F90
# gr_mpoleHeapsort.F90		     Simulation_computeAnalytical.F90
# gr_mpoleInit.F90		     Simulation_customizeProlong.F90
# gr_mpoleInterface.F90		     Simulation_data.F90
# gr_mpoleLocalSum.F90		     Simulation_defineDomain.F90
# gr_mpoleMom1Dspherical.F90	     Simulation_finalize.F90
# gr_mpoleMom2Dcylindrical.F90	     Simulation_getRenormGroup.F90
# gr_mpoleMom2Dspherical.F90	     Simulation_getVarnameType.F90
# gr_mpoleMom3Dcartesian.F90	     Simulation_initBlock.F90
# gr_mpoleMoments.F90		     Simulation_init.F90
# gr_mpolePot1Dspherical.F90	     Simulation_initParticleAttrib.F90
# gr_mpolePot2Dcylindrical.F90	     Simulation_initRestart.F90
# gr_mpolePot2Dspherical.F90	     Simulation_initSpecies.F90
# gr_mpolePot3Dcartesian.F90	     Simulation_interface.F90
# gr_mpolePotential.F90		     Simulation_mapIntToStr.F90
# gr_mpolePotentials.F90		     Simulation_mapParticlesVar.F90
# gr_mpolePrintRadialInfo.F90	     Simulation_mapStrToInt.F90
# gr_mpoleRad1Dspherical.F90	     Simulation_sendOutputData.F90
# gr_mpoleRad2Dcylindrical.F90	     SpeciesList.txt
# gr_mpoleRad2Dspherical.F90	     states.F90
# gr_mpoleRad3Dcartesian.F90	     Stir_computeDt.F90
# gr_mpoleRadialSampling.F90	     Stir.F90
# gr_mpoleSetDampingFactors.F90	     Stir_finalize.F90
# gr_mpoleSetInnerZoneGrid.F90	     Stir_init.F90
# gr_mpoleSetOuterZoneGrid.F90	     Stir_interface.F90
# gr_mpoleSphABTerms.F90		     test_multigrid.F90
# gr_mpoleSphBlkPotential.F90	     timer.fh
# gr_packBCs.F90			     Timers_data.F90
# gr_pfftFinalize.F90		     Timers_finalize.F90
# gr_pfftInit.F90			     Timers_getSummary.F90
# gr_pfftInterface.F90		     Timers.h
# gr_pfftInterfaceTypeDecl.F90	     Timers_init.F90
# gr_pfftPoissonDirect.F90	     Timers_interface.F90
# gr_primitiveToConserve.F90	     Timers_reset.F90
# gr_ptAdvance.F90		     Timers_start.F90
# gr_ptApplyBC.F90		     Timers_stop.F90
# gr_ptData.F90			     timings.F90
# gr_ptFillBlkParticleInfo.F90	     tmr_buildSummary.F90
# gr_ptFinalize.F90		     tmr_create.F90
# gr_ptHandleExcess.F90		     tmr_etime.F90
# gr_ptInit.F90			     tmr_findTimerIndex.F90
# gr_ptInterface.F90		     tmr_getMaxCallStackDepth.F90
# gr_ptLocalMatch.F90		     tmr_getMaxTimerParents.F90
# gr_ptMapInit.F90		     tmr_init.F90
# gr_ptMarkRefineDerefine.F90	     tmr_lookupIndex.F90
# gr_ptMove.F90			     tmr_stackLib.F90
# gr_ptMoveOffBlk.F90		     tracer.fh
# gr_ptMoveSieve.F90		     tree.F90
# gr_ptNextProcPair.F90		     tree_search_for_surrblks.F90
# gr_ptOneFaceBC.F90		     Turb_calc.F90
# gr_ptResetIndices.F90		     Turb_finalize.F90
# gr_ptResetProcPair.F90		     Turb_init.F90
# gr_ptSetIndices.F90		     Turb_interface.F90
# gr_ptSieveInterface.F90		     umap.F
# gr_ptVerifyBlock.F90		     umap.h
# gr_recreateDomain.F90		     Units
# gr_releaseInteriorBlkPtr.F90	     Units.bak
# gr_restrictTree.F90		     user_coord_transfm.F90
# gr_sanitizeDataAfterInterp.F90	     ut_conversionInterface.F90
# gr_sbCreateGroups.F90		     ut_convertToArrayIndicies.F90
# gr_sbCreateParticles.F90	     ut_convertToMemoryOffset.F90
# gr_sbFinalize.F90		     ut_cubicRealRoots.F90
# gr_sbGetProcBlock.F90		     ut_fndpos.F90
# gr_sbInit.F90			     ut_getFreeFileUnit.F90
# gr_sbInterface.F90		     ut_hunt.F90
# gr_sbSendForces.F90		     ut_insertSort.F90
# gr_sbSendParticleCount.F90	     ut_interpolationInterface.F90
# gr_sbSendParticles.F90		     ut_polint.F90
# gr_sbSendPosn.F90		     ut_quadraticInterpol.F90
# gr_sbStoreParticlesPerProc.F90	     ut_quadraticRealRoots.F90
# gr_sbUpdateForces.F90		     ut_quarticRealRoots.F90
# gr_searchNeighbor.F90		     ut_sortInterface.F90
# gr_setBlockType.F90		     ut_sortOnProcs.F90
# gr_setDataStructInfo.F90	     ut_sysMemData.F90
# gr_setGcFillNLayers.F90		     ut_sysMem.h
# gr_setMasks.F90			     ut_sysMemInterface.F90
# gr_setMaxRefineByTime.F90	     ut_sysMemStats.F90
# gr_solversFinalize.F90		     ut_sysMemSummaryStats.F90
# gr_solversInit.F90		     ut_sys_mem_usage.c
# gr_unmarkRefineByLogRadius.F90	     Viscosity.F90
# gr_updateData.F90		     Viscosity_finalize.F90
# gr_updateRefinement.F90		     Viscosity_init.F90
# gr_zoneMoments.F90		     Viscosity_interface.F90
# gr_zonePotential.F90		     workspace.F90
# hdf5_flash.h			     write_blocks_chombo_r4.c
# Heat_computeDt.F90		     write_blocks_chombo_r8.c
# Heatexchange_computeDt.F90	     write_blocks_hdf5_r4.c
# Heatexchange.F90		     write_blocks_hdf5_r8.c
# Heatexchange_finalize.F90
# (py2)
# : 1

# %% [markdown]
# The `make` command reads the makefiles in this directory and compiles `Flash`. The `-j` option to `make` uses multiple CPU threads to parallelize the compilation. Because there are many source files, this speeds up compilation by using a set of threads to simultaneously compile multiple source files at once.

# %%
make -j
# Out:
# Calculating dependencies
# ./setup_depends.py --generateINTERMEDIATElines -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -I /include -DH5_USE_16_API -O3  -c *.f *.f90 *.F90 *.F
# ./setup_addcdepends.py -I /include -DH5_USE_16_API -O3  -c *.c
# rm -f reorder.sh
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Burn_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 fl_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 ut_sysMemData.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 fl_fsConeData.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Conductivity_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Diffuse_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_interfaceTypeDecl.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_ptInterface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Gravity_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_ptSieveInterface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Opacity_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 io_c_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 paramesh_dimensions.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 sim_local_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 pt_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_hgInterface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Logfile_data.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Eos_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 IOParticles_data.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 io_ptInterface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_ptData.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Flame_data.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Driver_data.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Deleptonize_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Particles_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 fl_fsInterface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 RuntimeParameters_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 eos_localInterface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Viscosity_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 pc_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 IO_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Multispecies_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 eos_helmData.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 NSE_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Heat_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_bhInterface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Cosmology_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Stir_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 paramesh_comm_data.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 constants.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Hydro_data.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 PhysicalConstants_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 hy_ppm_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_bcInterface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Driver_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 NSE_data.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Simulation_data.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 fl_effData.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 fl_fsAtwoodInterface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_data.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Timers_data.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 paramesh_interfaces.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Gravity_data.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 paramesh_mpi_interfaces.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Profiler_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 fl_fsAtwoodData.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Ionize_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 PhysicalConstants_data.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_sbInterface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_GCScratchData.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Heatexchange_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_bcData.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Flame_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 RadTrans_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 fl_effInterface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 eos_helmInterface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_pfftInterfaceTypeDecl.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 fl_fsLaminarInterface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Turb_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Timers_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 MagneticResistivity_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Hydro_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Cool_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Polytrope_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_flashHook_interfaces.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 ut_interpolationInterface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_mpoleData.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_bicgInterface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 fl_fsData.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 ut_sortInterface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 io.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 eos_vecData.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Particles_data.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 eos_helmConstData.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Simulation_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 EnergyDeposition_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 fl_fsTFIInterface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Logfile_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 MassDiffusivity_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Burn_data.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Eos_data.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_mgInterface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Burn_computeDt.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Burn_finalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Burn_nseAtDens.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Burn_nseAtPres.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Conductivity_finalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Conductivity_init.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Cool.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Cool_computeDt.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Cool_finalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Cool_init.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Cool_unitTest.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Cosmology_cdmPowerSpectrum.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Cosmology_computeDt.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Cosmology_finalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Cosmology_getOldRedshift.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Cosmology_getParams.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Cosmology_getRedshift.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Cosmology_init.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Cosmology_massToLength.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Cosmology_redshiftHydro.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Cosmology_redshiftToTime.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Cosmology_sendOutputData.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Cosmology_solveFriedmannEqn.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Deleptonize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Deleptonize_finalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Deleptonize_getBounce.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Deleptonize_init.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Diffuse.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Diffuse_advance1D.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Diffuse_computeDt.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Diffuse_finalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Diffuse_fluxLimiter.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Diffuse_init.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Diffuse_solveScalar.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Diffuse_species.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Diffuse_therm.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Diffuse_visc.F90
# mpicc -I /include -DH5_USE_16_API -O3  -c -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Driver_abortFlashC.c
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Driver_superTimeStep.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 EnergyDeposition.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 EnergyDeposition_finalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 EnergyDeposition_init.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Eos_logDiagnostics.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Flame_finalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Flame_laminarSpeed.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Gravity_computeDt.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Gravity_finalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_advanceDiffusion.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_computeUserVars.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_formatNonRep.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_getBoundboxCentroids.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_getVarNonRep.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_mapParticlesToMesh.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_markRefineSpecialized.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_outsideBoundBox.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_parseNonRep.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_pfft.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_pfftFinalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_pfftGetIndexLimits.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_pfftInit.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_pfftMapFromOutput.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_pfftMapToInput.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_sbBroadcastParticles.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_sbSelectMaster.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_solidBodyUnitTest.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_unitTest.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_updateSolidBodyForces.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Heat.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Heat_computeDt.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Heat_finalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Heat_init.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Heatexchange.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Heatexchange_computeDt.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Heatexchange_finalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Heatexchange_init.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Hydro_sendOutputData.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 IO_finalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 IO_readUserArray.F90
# test -f io_flash.h && touch io_flash.h
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 IO_writeUserArray.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Ionize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Ionize_equil.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Ionize_finalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Ionize_init.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Logfile_finalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Logfile_getDateTimeStr.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 MagneticResistivity.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 MagneticResistivity_finalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 MagneticResistivity_init.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 MassDiffusivity.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 MassDiffusivity_finalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 MassDiffusivity_init.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Multispecies_finalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Multispecies_getAvg.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Multispecies_getPropertyVector.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Multispecies_getSum.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Multispecies_getSumFrac.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Multispecies_getSumInv.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Multispecies_getSumSqr.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Multispecies_init.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Multispecies_list.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Multispecies_unitTest.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Opacity.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Opacity_finalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Opacity_init.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Opacity_unitTest.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Paramesh_finalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Particles_accumCount.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Particles_longRangeForce.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Particles_mapToMeshOneBlk.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Particles_shortRangeForce.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Particles_sinkAccelSinksOnGas.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Particles_sinkAdvance.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Particles_sinkAdvanceParticles.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Particles_sinkComputeDt.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Particles_sinkInit.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Particles_sinkMarkRefineDerefine.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Particles_sinkMoveParticles.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Particles_sinkSendOutputData.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Particles_sinkSyncWithParticles.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Particles_unitTest.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Polytrope.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Polytrope_finalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Polytrope_init.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 PrimordialChemistry.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 PrimordialChemistry_computeDt.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 PrimordialChemistry_finalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 PrimordialChemistry_init.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 PrimordialChemistry_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Profiler_getSummary.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Profiler_init.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Profiler_start.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Profiler_stop.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 RadTrans.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 RadTrans_computeDt.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 RadTrans_finalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 RadTrans_mgdEFromT.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 RadTrans_mgdGetBound.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 RadTrans_mgdSetBc.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 RadTrans_mgdSetBound.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 RadTrans_mgdSetEnergy.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 RadTrans_planckInt.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 RadTrans_sumEnergy.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 RuntimeParameters_finalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 RuntimeParameters_mapStrToInt.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Simulation_adjustEvolution.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Simulation_computeAnalytical.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Simulation_customizeProlong.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Simulation_defineDomain.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Simulation_finalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Simulation_getRenormGroup.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Simulation_getVarnameType.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Simulation_initParticleAttrib.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Simulation_initRestart.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Simulation_mapParticlesVar.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Simulation_sendOutputData.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Stir.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Stir_computeDt.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Stir_finalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Stir_init.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Timers_finalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Turb_calc.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Turb_finalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Turb_init.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Viscosity.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Viscosity_finalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Viscosity_init.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 amr_1blk_cc_prol_gen_work_fun.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 amr_q_sort.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 amr_q_sort_real.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 amr_restrict_ec_user.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 amr_restrict_fc_user.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 amr_restrict_nc_user.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 amr_restrict_unk_user.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 amr_restrict_work_user.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 clean_field.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 coeff.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 concatStringWithInt.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 current_date_time.F90
# mpicc -I /include -DH5_USE_16_API -O3  -c -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 dr_set_rlimits.c
# mpicc -I /include -DH5_USE_16_API -O3  -c -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 dr_sleep.c
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 eos_idealGamma.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 eos_idealGamma3T.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 eos_initGamma.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 eos_initMgamma.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 eos_initMtemp.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 eos_initNuclear.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 eos_initTabulated.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 eos_mgamma.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 eos_mtemp.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 eos_nuclear.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 eos_tabFinalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 eos_tabIonmix.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 eos_tabulated.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 findWords.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 fl_effFinalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 fl_fsFinalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 fl_fsTFIFinalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 fl_fsTFIFlameSpeedBlock.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 fl_fsTFIFunc.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 fl_fsTFIGcMask.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 fl_fsTFIInit.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 fl_fsUnburnDens.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_GCTransferOneBlk.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_bcFinalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_bcHseInit.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_bhFinalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_bhInit.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_bicgFinalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_bicgInit.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_bicgMapBcType.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_findWhichChild.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_findWhichChildren.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_getIndex.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_hgFinalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_hgInit.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_hgMapBcType.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_hgPfftFinalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_hgPfftInit.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_hg_amr_1blk_bcset_work.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_hypreAddGraph.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_hypreApplyBcToFace.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_hypreComputeB.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_hypreCreateMatrix.F90
# ...
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 pt_mapFromMeshWeighted.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 pt_mapStringParamToInt.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 pt_setDataStructures.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 pt_setMask.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 pt_updateTypeDS.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_interface.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Eos_getAbarZbar.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_init.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_renormMassScalars.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 IO_init.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 IO_readCheckpoint.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 IO_writeCheckpoint.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 IO_writeParticles.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Logfile_create.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Logfile_stampVarMask.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Particles_initData.F90
# if [ -s "fl_fsConeData.mod" -a "fl_fsConeData.mod" -nt "fl_fsconedata.mod" ];then ln -f fl_fsConeData.mod fl_fsconedata.mod;else test -f fl_fsconedata.mod&&touch fl_fsconedata.mod||/bin/true;fi
# if [ -s "Gravity_interface.mod" -a "Gravity_interface.mod" -nt "gravity_interface.mod" ];then ln -f Gravity_interface.mod gravity_interface.mod;else test -f gravity_interface.mod&&touch gravity_interface.mod||/bin/true;fi
# if [ -s "fl_fsData.mod" -a "fl_fsData.mod" -nt "fl_fsdata.mod" ];then ln -f fl_fsData.mod fl_fsdata.mod;else test -f fl_fsdata.mod&&touch fl_fsdata.mod||/bin/true;fi
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Gravity_accelListOfBlocks.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 fl_fsConeInterp.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 fl_fsLaminarFinalize.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 fl_fsLaminarInit.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 fl_flameSpeed.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 fl_fsAtwoodInitTable.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 fl_fsInit.F90
# if [ -s "Profiler_interface.mod" -a "Profiler_interface.mod" -nt "profiler_interface.mod" ];then ln -f Profiler_interface.mod profiler_interface.mod;else test -f profiler_interface.mod&&touch profiler_interface.mod||/bin/true;fi
# if [ -s "Simulation_data.mod" -a "Simulation_data.mod" -nt "simulation_data.mod" ];then ln -f Simulation_data.mod simulation_data.mod;else test -f simulation_data.mod&&touch simulation_data.mod||/bin/true;fi
# if [ -s "Eos_interface.mod" -a "Eos_interface.mod" -nt "eos_interface.mod" ];then ln -f Eos_interface.mod eos_interface.mod;else test -f eos_interface.mod&&touch eos_interface.mod||/bin/true;fi
# if [ -s "RadTrans_interface.mod" -a "RadTrans_interface.mod" -nt "radtrans_interface.mod" ];then ln -f RadTrans_interface.mod radtrans_interface.mod;else test -f radtrans_interface.mod&&touch radtrans_interface.mod||/bin/true;fi
# if [ -s "Hydro_interface.mod" -a "Hydro_interface.mod" -nt "hydro_interface.mod" ];then ln -f Hydro_interface.mod hydro_interface.mod;else test -f hydro_interface.mod&&touch hydro_interface.mod||/bin/true;fi
# if [ -s "Stir_interface.mod" -a "Stir_interface.mod" -nt "stir_interface.mod" ];then ln -f Stir_interface.mod stir_interface.mod;else test -f stir_interface.mod&&touch stir_interface.mod||/bin/true;fi
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Eos_guardCells.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Eos_wrapped.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_markRefineDerefine.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Simulation_init.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Simulation_initBlock.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 bn_paraBurn.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_expandDomain.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_makeMaskConsistent.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_updateRefinement.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 sim_interpolate1dWd.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Burn.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Driver_evolveFlash.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Driver_finalizeFlash.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Driver_initFlash.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Driver_verifyInitDt.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 IO_updateScalars.F90
# if [ -s "Viscosity_interface.mod" -a "Viscosity_interface.mod" -nt "viscosity_interface.mod" ];then ln -f Viscosity_interface.mod viscosity_interface.mod;else test -f viscosity_interface.mod&&touch viscosity_interface.mod||/bin/true;fi
# Grid_conserveField.F90:213:0:
#
#  #endif !endif FLASH_NEDGE_VAR > 0
#
# Warning: extra tokens at end of #endif directive
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Driver_initMaterialProperties.F90
# mpi_amr_tree_setup.F90:89:0:
#
#  #ifdef SAVE_MORTS &
#
# Warning: extra tokens at end of #ifdef directive
# mpi_pack_tree_info.F90:71:0:
#
#  #ifdef SAVE_MORTS &
#
# Warning: extra tokens at end of #ifdef directive
# mpi_unpack_tree_info.F90:58:0:
#
#  #ifdef SAVE_MORTS &
#
# Warning: extra tokens at end of #ifdef directive
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_GCPutScratch.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_GCTransferOneBlk.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_fillGuardCells.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_getBlkBC.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_getBlkData.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_getPlaneData.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_getPointData.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_getRowData.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_initDomain.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_putBlkData.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_putPlaneData.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_putPointData.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_putRowData.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Grid_updateRefinement.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 amr_1blk_bcset.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_checkGridState.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_createDomain.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_findAllNeghID.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_findNeghID.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_ptLocalMatch.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_ptMoveOffBlk.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 gr_recreateDomain.F90
# if [ -s "Burn_interface.mod" -a "Burn_interface.mod" -nt "burn_interface.mod" ];then ln -f Burn_interface.mod burn_interface.mod;else test -f burn_interface.mod&&touch burn_interface.mod||/bin/true;fi
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Hydro.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 hy_ppm_sweep.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 hydro_1d.F90
# io_xfer_cont_slab.c: In function ‘io_xfer_cont_slab_’:
# if [ -s "fl_effData.mod" -a "fl_effData.mod" -nt "fl_effdata.mod" ];then ln -f fl_effData.mod fl_effdata.mod;else test -f fl_effdata.mod&&touch fl_effdata.mod||/bin/true;fi
# if [ -s "PhysicalConstants_data.mod" -a "PhysicalConstants_data.mod" -nt "physicalconstants_data.mod" ];then ln -f PhysicalConstants_data.mod physicalconstants_data.mod;else test -f physicalconstants_data.mod&&touch physicalconstants_data.mod||/bin/true;fi
# io_xfer_cont_slab.c:80:5: warning: implicit declaration of function ‘Driver_abortFlashC’ [-Wimplicit-function-declaration]
#      Driver_abortFlashC("[io_xfer_cont_slab]: Unknown I/O");
#      ^~~~~~~~~~~~~~~~~~
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Driver_computeDt.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Driver_finalizeSourceTerms.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Driver_initSourceTerms.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Driver_sourceTerms.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Flame_rhJump.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 Flame_rhJumpReactive.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 fl_effInit.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 pc_utilities.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 PhysicalConstants_get.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 PhysicalConstants_init.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 PhysicalConstants_list.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 PhysicalConstants_listUnits.F90
# if [ -s "local_tree.mod" -a "local_tree.mod" -nt "local_tree_module.mod" ];then ln -f local_tree.mod local_tree_module.mod;else test -f local_tree_module.mod&&touch local_tree_module.mod||/bin/true;fi
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 find_surrblks.F90
# if [ -s "find_surrblks.mod" -a "find_surrblks.mod" -nt "local_tree_common.mod" ];then ln -f find_surrblks.mod local_tree_common.mod;else test -f local_tree_common.mod&&touch local_tree_common.mod||/bin/true;fi
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 local_tree_build.F90
# mpif90 -c -O3 -fdefault-real-8 -fdefault-double-8 -ffree-line-length-none  -DMAXBLOCKS=10000 -DNXB=16 -DNYB=16 -DNZB=1 -DN_DIM=2 tree_search_for_surrblks.F90
# Linking in Units and Libraries

# %% [markdown]
# And we see that after compilation, the executable `flash4` is produced.

# %%
ls flash4
# Out:
# flash4
# (py2)
# : 1

# %% [markdown]
# Compilation also produced a few other files that we'll need to actually run `Flash` so I made a handy `packageFlash.sh` script to bundle everything we need in a tarball. It's in the `build` directory of `Flash` and let's quickly inspect its contents using the `cat` command.
#
# This just uses `tar` to package `flash.par`, `*.dat`, `*.txt`, and the executable `flash4` into the tarball `flashbinary.tar.gz`, compressed with `gzip`.

# %%
ls ../.
cat ../packageFlash.sh
# Out:
# object_snia_ddt				objectSNIa_hddt
# objectSNIaDDT				object_snia_hddt_alan
# objectSNIaDDT_Build001			object_snia_hddt.bak
# objectSNIaDDT_Build002			object_snia_hddt_old
# objectSNIaDDT_Build003_Pavel_debugging	object_snia_hddt_v2
# objectSNIaDDT_Build004			packageFlash.sh
# (py2) tar -chz --file=flashbinary.tar.gz flash.par *.dat *.txt flash4
# (py2)
# : 1

# %% [markdown]
# Let's copy `packageFlash.sh` into the build directory and run it. It will produce the file `flashbinary.tar.gz`

# %%
cp ../packageFlash.sh .
./packageFlash.sh
ls *.gz
# Out:
# (py2) (py2) flashbinary.tar.gz
# (py2)
# : 1

# %% [markdown]
# Finally we don't need python 2 anymore so we can deactivate the python 2 environment by doing the following:

# %%
source deactivate

# %% [markdown]
# ## Running Flash

# %% [markdown]
# Okay, now we're finally ready to run `Flash` so let's start by going to the top-level `Flash` directory, navigating to our build directory, and locating the `flashbinary.tar.gz` file we created in the previous section.

# %%
cd ~/codes/astro/flash/autoDDT_dens_thresh
ls
# Out:
# bin    LICENSE		     setup		      setup_snia_ddt.sh   tools
# build  obj_GradDetParamBurn  setup_alt		      setup_snia_hddt.sh
# docs   RELEASE		     setup_commands	      sites
# lib    RELEASE-NOTES	     setup_snia_ddt_htest.sh  source

# %%
cd build/object_snia_ddt
ls *.gz
# Out:
# flashbinary.tar.gz

# %% [markdown]
# I'm going to copy that tarball into an empty directory for running `Flash` - `~/scratch/runflash` will do just fine.

# %%
cp flashbinary.tar.gz ~/scratch/runflash/.
cd ~/scratch/runflash
ls
# Out:
# flashbinary.tar.gz

# %% [markdown]
# Now I'll untar the tarball, yielding `flash4` and lots of other files the `Flash` program needs to run.

# %%
tar -zxvf flashbinary.tar.gz
# Out:
# flash.par
# cc_7e8_linear_wd_plain.dat
# helm_table.dat
# CONeFlameTable.txt
# nse_dens_emq_table.txt
# nse_pres_hmq_table.txt
# SpeciesList.txt
# flash4

# %% [markdown]
# The next step is to copy a model file and a parameter file into my run directory. For this example, I'm going to use the CO WD model from my hybrid paper, located in the `Flash-Star/hybrid-paper-1` repository. I'm also going to copy in the parameter file `flash.par` from realization number `001`, in the same repository.
#
# (In the below, I'm only using the bash variables `INPUTS_DIR` and `COWD_DIR` because the jupyter notebook I'm writing this in will cut off long lines.)

# %%
INPUTS_DIR=~/codes/astro/Flash-Star/hybrid-paper-1/flash-inputs
COWD_DIR=$INPUTS_DIR/co_realizations_inputs_rhoddt7.2
cp $COWD_DIR/400k_Tc7e8_cf-Brendan_flash.dat .
cp $COWD_DIR/Realization_001/flash.par .
ls
# Out:
# 400k_Tc7e8_cf-Brendan_flash.dat			CONeFlameTable.txt
# 400k_Tc7e8_co_wd_R001.dat			flash4
# 400k_Tc7e8_co_wd_R001_forced_hdf5_plt_cnt_0000	flashbinary.tar.gz
# 400k_Tc7e8_co_wd_R001_hdf5_chk_0000		flash.par
# 400k_Tc7e8_co_wd_R001_hdf5_chk_0001		flash.par~
# 400k_Tc7e8_co_wd_R001_hdf5_part_0000		helm_table.bdat
# 400k_Tc7e8_co_wd_R001_hdf5_plt_cnt_0000		helm_table.dat
# 400k_Tc7e8_co_wd_R001.log			nse_dens_emq_table.txt
# amr_runtime_parameters.dump			nse_pres_hmq_table.txt
# cc_7e8_linear_wd_plain.dat			SpeciesList.txt

# %% [markdown]
# For the purposes of this example, I set the maximum number of timesteps to 10 so `Flash` will stop quickly.
#
# The parameter file `flash.par` contains all the runtime parameters `Flash` uses to determine simulation settings, which input stellar model file to use, what to name output files, when to stop the simulation, etc.
#
# I just opened the parameter file `flash.par` in `emacs` and changed the line reading:
#
# `nend = 999999`
#
# to:
#
# `nend = 10`
#
# and saved it.

# %%
emacs flash.par
# Out:
# (emacs:4664): Gtk-WARNING **: Allocating size to Emacs 0x34c02a0 without calling gtk_widget_get_preferred_width/height(). How does the code know the size to allocate?

# %% [markdown]
# Finally I ran `Flash` - it automatically looks for `flash.par` in the current directory and reads it to get the runtime parameters. `Flash` will initialize the simulation and begin taking timesteps to advance the hydrodynamics and other simulation physics. Since I set `nend = 10`, the simulation will stop after just 10 timesteps.

# %%
./flash4
# Out:
#  RuntimeParameters_read:  ignoring unknown parameter "bn_autoDet"...
#  RuntimeParameters_read:  ignoring unknown parameter "cfl_ini"...
#  NOTE: Enabling curvilinear, cartesian_pm/cylindrical_pm/spherical_pm/polar_pm is  F F F F
#  MaterialProperties initialized
#  Cosmology initialized
#  about to open file
#  [Eos_init] Cannot open helm_table.bdat!
#  [Eos_init] Trying old helm_table.dat!
#  [EOS Helmholtz] WARNING!  Mask setting does not speed up Eos Helmholtz calls
#  Source terms initialized
#   iteration, no. not moved =            0           0
#  refined: total leaf blocks =            2
#  refined: total blocks =            2
#  INFO: Grid_fillGuardCells is ignoring masking.
#   iteration, no. not moved =            0           0
#  refined: total leaf blocks =            8
#  refined: total blocks =           10
#   iteration, no. not moved =            0           2
#   iteration, no. not moved =            1           0
#  refined: total leaf blocks =           14
#  refined: total blocks =           18
#   iteration, no. not moved =            0           5
#   iteration, no. not moved =            1           0
#  refined: total leaf blocks =           20
#  refined: total blocks =           26
#   iteration, no. not moved =            0           8
#   iteration, no. not moved =            1           0
#  refined: total leaf blocks =           26
#  refined: total blocks =           34
#   iteration, no. not moved =            0          13
#   iteration, no. not moved =            1           0
#  refined: total leaf blocks =           32
#  refined: total blocks =           42
#   iteration, no. not moved =            0          15
#   iteration, no. not moved =            1           0
#  refined: total leaf blocks =           98
#  refined: total blocks =          130
#   iteration, no. not moved =            0          66
#   iteration, no. not moved =            1           0
#  refined: total leaf blocks =          176
#  refined: total blocks =          234
#   iteration, no. not moved =            0          90
#   iteration, no. not moved =            1           0
#  refined: total leaf blocks =          272
#  refined: total blocks =          362
#   iteration, no. not moved =            0         213
#   iteration, no. not moved =            1           0
#  refined: total leaf blocks =          293
#  refined: total blocks =          390
#   iteration, no. not moved =            0         214
#   iteration, no. not moved =            1           0
#  refined: total leaf blocks =          338
#  refined: total blocks =          450
#  [gr_mpoleInit] using 74003 moment array, 2072084 items
#   Finished with Grid_initDomain, no restart
#  Ready to call Hydro_init
#  Info: Hydro_init has set hy_specialFluxVars to            3
#  Hydro initialized
#  Gravity initialized
#  ***********************************************************
#   Warning: The initial timestep is too large.
#     initial timestep =    1.0000000000000000
#     CFL timestep     =    2.1311570186797484E-004
#   Resetting dtinit to TIMESTEP_SLOW_START_FACTOR*dtcfl.
#  ***********************************************************
#
#  Initial dt verified
#  *** Wrote checkpoint file to 400k_Tc7e8_co_wd_R001_hdf5_chk_0000 ****
#  *** Wrote plotfile to 400k_Tc7e8_co_wd_R001_hdf5_plt_cnt_0000 ****
#  *** Wrote particle file to 400k_Tc7e8_co_wd_R001_hdf5_part_0000 ****
#  Initial plotfile written
#  Driver init all done
#        n          t         dt  (         x,          y,          z) |  dt_hydro  dt_Part
#        1 4.2623E-05 2.5574E-05  ( 2.000E+05,  2.000E+05,  0.000E+00) |  2.131E-04 2.494E+00
#        2 9.3771E-05 3.0689E-05  ( 2.000E+05,  2.000E+05,  0.000E+00) |  2.131E-04 1.466E+00
#        3 1.5515E-04 3.6826E-05  ( 2.000E+05,  2.000E+05,  0.000E+00) |  2.131E-04 7.715E-01
#        4 2.2880E-04 4.4192E-05  ( 2.000E+05,  2.000E+05,  0.000E+00) |  2.131E-04 4.909E-01
#        5 3.1718E-04 5.3030E-05  ( 2.000E+05,  2.000E+05,  0.000E+00) |  2.131E-04 3.421E-01
#        6 4.2324E-04 6.3636E-05  ( 2.000E+05,  2.000E+05,  0.000E+00) |  2.131E-04 2.512E-01
#        7 5.5052E-04 7.6363E-05  ( 1.400E+06, -2.000E+05,  0.000E+00) |  2.131E-04 1.907E-01
#        8 7.0324E-04 9.1636E-05  ( 1.400E+06, -2.000E+05,  0.000E+00) |  2.131E-04 1.483E-01
#        9 8.8651E-04 1.0996E-04  ( 2.000E+05,  2.200E+06,  0.000E+00) |  2.131E-04 1.174E-01
#   iteration, no. not moved =            0         341
#   iteration, no. not moved =            1           0
#  refined: total leaf blocks =          350
#  refined: total blocks =          466
#       10 1.1064E-03 1.3196E-04  ( 2.000E+05,  2.200E+06,  0.000E+00) |  2.131E-04 9.448E-02
#  *** Wrote checkpoint file to 400k_Tc7e8_co_wd_R001_hdf5_chk_0001 ****
#  *** Wrote plotfile to 400k_Tc7e8_co_wd_R001_forced_hdf5_plt_cnt_0000 ****

# %% [markdown]
# I can then have a look at the new files the simulation created.
#
# `400k_Tc7e8_co_wd_R001.dat` - contains integral quantities like total kinetic energy, total burned mass, etc. It will be important for our later analysis.
#
# `400k_Tc7e8_co_wd_R001_hdf5_chk_0000` - a checkpoint file `Flash` creates periodically throughout the simulation: each successive checkpoint file will have a unique number at the end of the filename and `Flash` can read these files to restart a simulation at some time later than time zero if we want. This will be useful for running `Flash` in a cluster environment.
#
# `400k_Tc7e8_co_wd_R001_hdf5_part_0000` - a particle data file, these store the thermodynamic data collected by the non-interacting tracer particles, useful for postprocessing. These get unique numbers for different time steps.
#
# `400k_Tc7e8_co_wd_R001_hdf5_plt_cnt_0000` - a plot file, this stores data useful for plotting various quantities like density and temperature in the domain at a particular timestep. As for checkpoint and particle files, the number at the end is unique to the timestep. These files will be useful for making plots and movies showing how the explosion evolves.
#
# `400k_Tc7e8_co_wd_R001.log` - A text log file that tells you what `Flash` is doing and is useful for debugging and getting details about the simulation.

# %%
ls
# Out:
# 400k_Tc7e8_cf-Brendan_flash.dat			CONeFlameTable.txt
# 400k_Tc7e8_co_wd_R001.dat			flash4
# 400k_Tc7e8_co_wd_R001_forced_hdf5_plt_cnt_0000	flashbinary.tar.gz
# 400k_Tc7e8_co_wd_R001_hdf5_chk_0000		flash.par
# 400k_Tc7e8_co_wd_R001_hdf5_chk_0001		flash.par~
# 400k_Tc7e8_co_wd_R001_hdf5_part_0000		helm_table.bdat
# 400k_Tc7e8_co_wd_R001_hdf5_plt_cnt_0000		helm_table.dat
# 400k_Tc7e8_co_wd_R001.log			nse_dens_emq_table.txt
# amr_runtime_parameters.dump			nse_pres_hmq_table.txt
# cc_7e8_linear_wd_plain.dat			SpeciesList.txt
